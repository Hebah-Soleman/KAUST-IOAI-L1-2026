# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)

# %%
from sklearn.datasets import fetch_20newsgroups
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

newsgroups = fetch_20newsgroups(
    subset='all',
    remove=('headers', 'footers', 'quotes')
)

# %% [markdown]
# Tasks:
# - Explore the Dataset
#
#   * Examine the number of documents and categories.
#   * Display sample documents from different categories.
#   * Analyze class distribution.
#   * Calculate document length statistics (minimum, maximum, average).
#   * Visualize category frequencies.
#
# - Data Preprocessing
#
#   Perform text cleaning and preprocessing like:
#
#   * Convert text to lowercase.
#   * Remove punctuation.
#   * Remove special characters and numbers.
#   * Remove stopwords.
#   * Apply stemming or lemmatization.
#   * Remove extra whitespace.
#   * Compare a sample document before and after preprocessing.
#
# - Exploratory Text Analysis
#
#   * Identify the most frequent words in the corpus.
#   * Generate word frequency plots.
#   * Create word clouds for selected categories.
#   * Compare vocabulary across different categories.
#
# - Split the Dataset
#
#   * Divide the dataset into training and testing sets.
#   * Use an appropriate train-test split ratio.
#
# Experiment with Different Text Vectorization Techniques
#
#   Convert text into numerical features using multiple approaches:
#
#   1. Bag of Words (CountVectorizer)
#   2. TF-IDF Vectorizer
#   3. TF-IDF with N-grams (e.g., unigrams and bigrams)
#
#   For each vectorizer:
#
#   * Record vocabulary size.
#   * Analyze feature sparsity.
#   * Compare resulting feature matrices.
#
# - Train Multiple Machine Learning Models
#
# Train and evaluate several classifiers like:
#
#   1. Multinomial Naive Bayes
#   2. Logistic Regression
#   3. Linear Support Vector Machine (Linear SVM)
#   4. Random Forest
#   5. K-Nearest Neighbors (optional)
#
#   For each model:
#
#   * Train using the same feature representation.
#   * Generate predictions on the test set.
#
# - Evaluate Model Performance
#
#   For every model, calculate:
#
#   * Accuracy
#   * Precision
#   * Recall
#   * F1-Score
#   * Confusion Matrix
#
# Visualize:
#
#   * Confusion matrices
#   * Performance comparison charts
#
# - Compare Vectorization Methods
#
#
#   * CountVectorizer vs TF-IDF
#   * TF-IDF vs TF-IDF with N-grams
#
# Questions to answer:
#
# * Which representation gives the best accuracy?
# * Which produces the largest feature space?
# * Which is most computationally efficient?
#
# - Compare Machine Learning Models
#
# Create a comparison table:
#
# Model,	Vectorizer,	Accuracy,	Precision,	Recall,	F1 Score
#
#
# - Test on New Documents
#
# Example:
#
# Input:
# "NASA announced a new Mars exploration mission."
# Output:
# "sci.space"

# %%
df = pd.DataFrame({'news': newsgroups.data,
                   'category': [newsgroups.target_names[i] for i in newsgroups.target]})
df.head()
# Out:
#                                                 news                  category
# 0  \n\nI am sure some bashers of Pens fans are pr...          rec.sport.hockey
# 1  My brother is in the market for a high-perform...  comp.sys.ibm.pc.hardware
# 2  \n\n\n\n\tFinally you said what you dream abou...     talk.politics.mideast
# 3  \nThink!\n\nIt's the SCSI card doing the DMA t...  comp.sys.ibm.pc.hardware
# 4  1)    I have an old Jasmine drive which I cann...     comp.sys.mac.hardware

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18846 entries, 0 to 18845
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   news      18846 non-null  object
#  1   category  18846 non-null  object
# dtypes: object(2)
# memory usage: 294.6+ KB
